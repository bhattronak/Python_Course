# %%
import pandas as pd

# %%
#METHOD 1

stats=pd.read_csv('C:\\Users\\Ronak.Bhatt\\Desktop\\Python programming course\\DemographicData.csv')
#csv is extension of file DemographicData,in brecket write path of file which requires to open.

# %%
stats
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
#method 2

# %%
import os

# %%
print(os.getcwd())  #getcwd is get current working directory
# Out:
# C:\Users\Ronak.Bhatt\Desktop\Python programming course\Section 5

# %%
os.chdir('C:\\Users\\Ronak.Bhatt\\Desktop\\Python programming course')

# %%
print(os.getcwd())
# Out:
# C:\Users\Ronak.Bhatt\Desktop\Python programming course

# %%
stat2=pd.read_csv('DemographicData.csv')

# %%
stat2
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
#Exaploring Your Data

# %%
#1.Full data frame
stats
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
#Number of rows
len(stats)
# Out:
# 195

# %%
#3.See the column\
stats.columns
# Out:
# Index(['Country Name', 'Country Code', 'Birth rate', 'Internet users',
#        'Income Group'],
#       dtype='object')

# %%
#4.number of column
len(stats.columns)
# Out:
# 5

# %%
#5.top rows
stats.head(8)#rememner the bracket
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
# 5             Argentina          ARG      17.716            59.9
# 6               Armenia          ARM      13.308            41.9
# 7   Antigua and Barbuda          ATG      16.447            63.4
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income
# 7          High income

# %%
#6.Bottom rows
stats.tail(6)
# Out:
#          Country Name Country Code  Birth rate  Internet users  \
# 189             Samoa          WSM      26.172            15.3
# 190       Yemen, Rep.          YEM      32.947            20.0
# 191      South Africa          ZAF      20.850            46.5
# 192  Congo, Dem. Rep.          COD      42.394             2.2
# 193            Zambia          ZMB      40.471            15.4
# 194          Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 189  Lower middle income
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
#7.information on the columns
stats.info()#dont forget brecket
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    195 non-null    object
#  1   Country Code    195 non-null    object
#  2   Birth rate      195 non-null    float64
#  3   Internet users  195 non-null    float64
#  4   Income Group    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
#8.get statastics of data
stats.describe()
# Out:
#        Birth rate  Internet users
# count  195.000000      195.000000
# mean    21.469928       42.076471
# std     10.605467       29.030788
# min      7.900000        0.900000
# 25%     12.120500       14.520000
# 50%     19.680000       41.000000
# 75%     29.759500       66.225000
# max     49.661000       96.546800

# %%
stats.describe().transpose()
# Out:
#                 count       mean        std  min      25%    50%      75%  \
# Birth rate      195.0  21.469928  10.605467  7.9  12.1205  19.68  29.7595
# Internet users  195.0  42.076471  29.030788  0.9  14.5200  41.00  66.2250
#
#                     max
# Birth rate      49.6610
# Internet users  96.5468

# %% [markdown]
# ---

# %%
#Rename of columns names
stats.columns
# Out:
# Index(['Country Name', 'Country Code', 'Birth rate', 'Internet users',
#        'Income Group'],
#       dtype='object')

# %%
stats.columns=['a','b','c','d','e']

# %%
stats.head()
# Out:
#                       a    b       c     d                    e
# 0                 Aruba  ABW  10.244  78.9          High income
# 1           Afghanistan  AFG  35.253   5.9           Low income
# 2                Angola  AGO  45.985  19.1  Upper middle income
# 3               Albania  ALB  12.877  57.2  Upper middle income
# 4  United Arab Emirates  ARE  11.044  88.0          High income

# %%
stats.columns=['CountryName', 'CountryCode',\
               'BirthRate', 'InternetUsers', 'IncomeGroup']
#that \ says that code is continue in the next lines.

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %% [markdown]
# ---

# %%
#Subsetting dataframes in pandas

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
#Three parts. Bickle up
#How to subset by row?
#how to subset by columns?
#How to combined this two?

# %%
#Part 1- For rows
#just like slicing
stats[21:26]
#so how python know that in 21:26 we are talking about row only and not columns?So its by default
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 21      Belize         BLZ     23.092          33.60  Upper middle income
# 22     Bermuda         BMU     10.400          95.30          High income
# 23     Bolivia         BOL     24.236          36.94  Lower middle income
# 24      Brazil         BRA     14.931          51.04  Upper middle income
# 25    Barbados         BRB     12.188          73.00          High income

# %%
stats[:]#so it print everything
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
stats[185:]
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  \
# 185  Virgin Islands (U.S.)         VIR     10.700           45.3
# 186                Vietnam         VNM     15.537           43.9
# 187                Vanuatu         VUT     26.739           11.3
# 188     West Bank and Gaza         PSE     30.394           46.6
# 189                  Samoa         WSM     26.172           15.3
# 190            Yemen, Rep.         YEM     32.947           20.0
# 191           South Africa         ZAF     20.850           46.5
# 192       Congo, Dem. Rep.         COD     42.394            2.2
# 193                 Zambia         ZMB     40.471           15.4
# 194               Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 185          High income
# 186  Lower middle income
# 187  Lower middle income
# 188  Lower middle income
# 189  Lower middle income
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# ...

# %%
stats[:10]
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244        78.9000
# 1           Afghanistan         AFG     35.253         5.9000
# 2                Angola         AGO     45.985        19.1000
# 3               Albania         ALB     12.877        57.2000
# 4  United Arab Emirates         ARE     11.044        88.0000
# 5             Argentina         ARG     17.716        59.9000
# 6               Armenia         ARM     13.308        41.9000
# 7   Antigua and Barbuda         ATG     16.447        63.4000
# 8             Australia         AUS     13.200        83.0000
# 9               Austria         AUT      9.400        80.6188
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income
# 7          High income
# 8          High income
# 9          High income

# %%
#Quick exercise(refreshment)
#Revers the dataframe
stats[-1:-196:-1]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 194              Zimbabwe         ZWE     35.715           18.5
# 193                Zambia         ZMB     40.471           15.4
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 191          South Africa         ZAF     20.850           46.5
# 190           Yemen, Rep.         YEM     32.947           20.0
# ..                    ...         ...        ...            ...
# 4    United Arab Emirates         ARE     11.044           88.0
# 3                 Albania         ALB     12.877           57.2
# 2                  Angola         AGO     45.985           19.1
# 1             Afghanistan         AFG     35.253            5.9
# 0                   Aruba         ABW     10.244           78.9
#
#              IncomeGroup
# 194           Low income
# 193  Lower middle income
# 192           Low income
# 191  Upper middle income
# 190  Lower middle income
# ..                   ...
# ...

# %%
stats[::-1]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 194              Zimbabwe         ZWE     35.715           18.5
# 193                Zambia         ZMB     40.471           15.4
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 191          South Africa         ZAF     20.850           46.5
# 190           Yemen, Rep.         YEM     32.947           20.0
# ..                    ...         ...        ...            ...
# 4    United Arab Emirates         ARE     11.044           88.0
# 3                 Albania         ALB     12.877           57.2
# 2                  Angola         AGO     45.985           19.1
# 1             Afghanistan         AFG     35.253            5.9
# 0                   Aruba         ABW     10.244           78.9
#
#              IncomeGroup
# 194           Low income
# 193  Lower middle income
# 192           Low income
# 191  Upper middle income
# 190  Lower middle income
# ..                   ...
# ...

# %%
#Quick exercise(refreshment)
#Get incremental row of 20th order
stats[::20]
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 0         Aruba         ABW     10.244        78.9000          High income
# 20      Belarus         BLR     12.500        54.1700  Upper middle income
# 40   Costa Rica         CRI     15.022        45.9600  Upper middle income
# 60        Gabon         GAB     30.555         9.2000  Upper middle income
# 80        India         IND     20.291        15.1000  Lower middle income
# 100       Libya         LBY     21.425        16.5000  Upper middle income
# 120  Mozambique         MOZ     39.705         5.4000           Low income
# 140      Poland         POL      9.600        62.8492          High income
# 160    Suriname         SUR     18.455        37.4000  Upper middle income
# 180     Uruguay         URY     14.374        57.6900          High income

# %% [markdown]
# ---

# %%
#Part 2=Columns

# %%
stats.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
#How to get data of perticular columns
stats['CountryName']
# Out:
# 0                     Aruba
# 1               Afghanistan
# 2                    Angola
# 3                   Albania
# 4      United Arab Emirates
#                ...
# 190             Yemen, Rep.
# 191            South Africa
# 192        Congo, Dem. Rep.
# 193                  Zambia
# 194                Zimbabwe
# Name: CountryName, Length: 195, dtype: object

# %%
stats['CountryName'].head()
# Out:
# 0                   Aruba
# 1             Afghanistan
# 2                  Angola
# 3                 Albania
# 4    United Arab Emirates
# Name: CountryName, dtype: object

# %%
['CountryName','BirthRate']
# Out:
# ['CountryName', 'BirthRate']

# %%
stats[['CountryName','BirthRate']].head()#so inside square bracket we need list so one more square bracket is required.
# Out:
#             CountryName  BirthRate
# 0                 Aruba     10.244
# 1           Afghanistan     35.253
# 2                Angola     45.985
# 3               Albania     12.877
# 4  United Arab Emirates     11.044

# %%
#even order of list will also follow
stats[['BirthRate','CountryName',]].head()
# Out:
#    BirthRate           CountryName
# 0     10.244                 Aruba
# 1     35.253           Afghanistan
# 2     45.985                Angola
# 3     12.877               Albania
# 4     11.044  United Arab Emirates

# %%
#Quick Access-requires the name to be one word

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats['BirthRate']
# Out:
# 0      10.244
# 1      35.253
# 2      45.985
# 3      12.877
# 4      11.044
#         ...
# 190    32.947
# 191    20.850
# 192    42.394
# 193    40.471
# 194    35.715
# Name: BirthRate, Length: 195, dtype: float64

# %%
stats.BirthRate.head()
#so thats why we had rename because Birth Rate will not run here.
#But this is applicable for one column only
# Out:
# 0    10.244
# 1    35.253
# 2    45.985
# 3    12.877
# 4    11.044
# Name: BirthRate, dtype: float64

# %%
stats.CountryName.head()
# Out:
# 0                   Aruba
# 1             Afghanistan
# 2                  Angola
# 3                 Albania
# 4    United Arab Emirates
# Name: CountryName, dtype: object

# %%
#Part 3-Combining row and columns

# %%
stats[4:8][['BirthRate','CountryName',]]
# Out:
#    BirthRate           CountryName
# 4     11.044  United Arab Emirates
# 5     17.716             Argentina
# 6     13.308               Armenia
# 7     16.447   Antigua and Barbuda

# %%
stats[['CountryName','BirthRate','CountryName']][3:7]  #it will print in order and can be repeated.
# Out:
#             CountryName  BirthRate           CountryName
# 3               Albania     12.877               Albania
# 4  United Arab Emirates     11.044  United Arab Emirates
# 5             Argentina     17.716             Argentina
# 6               Armenia     13.308               Armenia

# %%
#so how its run actually?
#so a=stats['BirthRate','CountryName'] and then subset a[4:8],so we just did it both together.

# %% [markdown]
# ---

# %%
#Mathematical Operations:
result=stats.BirthRate * stats.InternetUsers

# %%
result
#Although it has no practial meaning,But thats how we can do multiplication;division,addition.substrections.
# Out:
# 0      808.2516
# 1      207.9927
# 2      878.3135
# 3      736.5644
# 4      971.8720
#          ...
# 190    658.9400
# 191    969.5250
# 192     93.2668
# 193    623.2534
# 194    660.7275
# Length: 195, dtype: float64

# %%
#How to Add column
stats['Mycalculation']=stats.BirthRate * stats.InternetUsers
#Because stats['x'] wikk gives you xth column which we have equalize to new created column named result or stats.BirthRate * stats.InternetUsers

# %%
stats.head()
#so column has been added.
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup  Mycalculation
# 0          High income       808.2516
# 1           Low income       207.9927
# 2  Upper middle income       878.3135
# 3  Upper middle income       736.5644
# 4          High income       971.8720

# %%
#Removing Column
stats.drop('Mycalculation',axis=1)
#do shift+tab to know about what to enter inside brecket of function,so here we entered Mycalculation but by default it'll take
#it as row but Mycalculation is column so we need to specify axis=1,by default axis=0 taken for row.
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
stats
#so Mycalculation is still here,so we need to assing stats=stats.drop('Mycalculation',axis=1)
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup  Mycalculation
# 0            High income       808.2516
# 1             Low income       207.9927
# 2    Upper middle income       878.3135
# ...

# %%
stats=stats.drop('Mycalculation',axis=1)

# %%
stats
#so now it has been removed
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %% [markdown]
# ---

# %%
#FILTERING THE DATA FRAMES
#Eg.all country starts with 'A',All BirthRate >20.etc...

# %%
#Filtering is about ROWS

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats.InternetUsers<2
#flase saying condition isnt match,True-its match
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# Name: InternetUsers, Length: 195, dtype: bool

# %%
Filter=stats.InternetUsers<2

# %%
Filter
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# Name: InternetUsers, Length: 195, dtype: bool

# %%
stats[Filter]
#So it print all True values
# Out:
#       CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 11        Burundi         BDI     44.151            1.3           Low income
# 52        Eritrea         ERI     34.800            0.9           Low income
# 55       Ethiopia         ETH     32.925            1.9           Low income
# 64         Guinea         GIN     37.337            1.6           Low income
# 117       Myanmar         MMR     18.119            1.6  Lower middle income
# 127         Niger         NER     49.661            1.7           Low income
# 154  Sierra Leone         SLE     36.729            1.7           Low income
# 156       Somalia         SOM     43.891            1.5           Low income
# 172   Timor-Leste         TLS     35.755            1.1  Lower middle income

# %%
#Awsome:Lets us it in practice
filter2=stats.BirthRate>40

# %%
stats[filter2]
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 2              Angola         AGO     45.985           19.1
# 11            Burundi         BDI     44.151            1.3
# 14       Burkina Faso         BFA     40.551            9.1
# 65        Gambia, The         GMB     42.525           14.0
# 115              Mali         MLI     44.138            3.5
# 127             Niger         NER     49.661            1.7
# 128           Nigeria         NGA     40.045           38.0
# 156           Somalia         SOM     43.891            1.5
# 167              Chad         TCD     45.745            2.3
# 178            Uganda         UGA     43.474           16.2
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
#
#              IncomeGroup
# 2    Upper middle income
# 11            Low income
# 14            Low income
# 65            Low income
# 115           Low income
# 127           Low income
# ...

# %%
#So no need to do filter every time,we can write directly but it might confusioning,so always think it as like Filter
stats[stats.BirthRate>40]
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 2              Angola         AGO     45.985           19.1
# 11            Burundi         BDI     44.151            1.3
# 14       Burkina Faso         BFA     40.551            9.1
# 65        Gambia, The         GMB     42.525           14.0
# 115              Mali         MLI     44.138            3.5
# 127             Niger         NER     49.661            1.7
# 128           Nigeria         NGA     40.045           38.0
# 156           Somalia         SOM     43.891            1.5
# 167              Chad         TCD     45.745            2.3
# 178            Uganda         UGA     43.474           16.2
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
#
#              IncomeGroup
# 2    Upper middle income
# 11            Low income
# 14            Low income
# 65            Low income
# 115           Low income
# 127           Low income
# ...

# %%
#Combining of Filters
stats[stats.BirthRate>40 and stats.InternetUsers<2]
#so why we get an error?
#Because Python is Object oriented lan,SO here logical operator and expect True or False on both side of it,well so not work for column or list.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-a5bf47ed716d> in <module>
#       1 #Combining of Filters
# ----> 2 stats[stats.BirthRate>40 and stats.InternetUsers<2]
#       3 #so why we get an error?
#       4 #Because Python is Object oriented lan,SO here logical operator and expect True or False on both side of it,well so not work for column or list.
#
# ~\3D Objects\New folder\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1477     def __nonzero__(self):
#    1478         raise ValueError(
# -> 1479             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1480             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1481         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
stats[Filter & filter2]
#so now it compare element by element

# %%
stats[stats.BirthRate>40 & stats.InternetUsers<2]
#so here python dont know which condition needs to run first so it will get confuse.
#so to remove this confusion we put () over conditions
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\3D Objects\New folder\lib\site-packages\pandas\core\ops\array_ops.py in na_logical_op(x, y, op)
#     273         #  (xint or xbool) and (yint or bool)
# --> 274         result = op(x, y)
#     275     except TypeError:
#
# ~\3D Objects\New folder\lib\site-packages\pandas\core\ops\roperator.py in rand_(left, right)
#      51 def rand_(left, right):
# ---> 52     return operator.and_(right, left)
#      53
#
# TypeError: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\3D Objects\New folder\lib\site-packages\pandas\core\ops\array_ops.py in na_logical_op(x, y, op)
# ...

# %%
stats[(stats.BirthRate>40) & (stats.InternetUsers<2)]
#its () brecket not []
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers IncomeGroup
# 11      Burundi         BDI     44.151            1.3  Low income
# 127       Niger         NER     49.661            1.7  Low income
# 156     Somalia         SOM     43.891            1.5  Low income

# %%
#Another example
stats[stats.IncomeGroup=='High income']
#So in the column of IncomeGroup where wvwe High Income writen those are printed.Just like find ctrl+F
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0                    Aruba         ABW     10.244          78.90  High income
# 4     United Arab Emirates         ARE     11.044          88.00  High income
# 5                Argentina         ARG     17.716          59.90  High income
# 7      Antigua and Barbuda         ATG     16.447          63.40  High income
# 8                Australia         AUS     13.200          83.00  High income
# ..                     ...         ...        ...            ...          ...
# 174    Trinidad and Tobago         TTO     14.590          63.80  High income
# 180                Uruguay         URY     14.374          57.69  High income
# 181          United States         USA     12.500          84.20  High income
# 184          Venezuela, RB         VEN     19.842          54.90  High income
# 185  Virgin Islands (U.S.)         VIR     10.700          45.30  High income
#
# [67 rows x 5 columns]

# %%
#How to get unique categories
stats.IncomeGroup.unique()
#so unique will return each unique element in the written row.
# Out:
# array(['High income', 'Low income', 'Upper middle income',
#        'Lower middle income'], dtype=object)

# %%
#Quick Exercise
#Find details of Malta
stats[stats.CountryName=='Malta']
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 116       Malta         MLT        9.5        68.9138  High income

# %% [markdown]
# ---

# %%
#Using .at()  and .iat()

# %%
#Accessing individual element

# %%
stats[2,2]
#It did worked at Matrix than why not here?
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\3D Objects\New folder\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: (2, 2)
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-88-673695811274> in <module>
# ----> 1 stats[2,2]
# ...

# %%
stats.head()

# %%
#.at -its for label.Important:even integer are treated as labels
#.iat- its for integers locations.

#to remember .at is like @ that cell, and iat is integer@ that cell.

# %%
stats.iat[3,4]
# Out:
# 'Upper middle income'

# %%
stats.iat[0,1]
#so it count just like in matrix,it take top left as (0,0) and go to your location
# Out:
# 'ABW'

# %%
stats.at[2,'BirthRate']
#so 2 says go to row which has label 2 and here we need to identify in BirthRate column
# Out:
# 45.985

# %%
#Why we need at if we have iat?

# %%
sub10=stats[::10]

# %%
sub10
# Out:
#      CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 0          Aruba         ABW     10.244      78.900000          High income
# 10    Azerbaijan         AZE     18.300      58.700000  Upper middle income
# 20       Belarus         BLR     12.500      54.170000  Upper middle income
# 30        Canada         CAN     10.900      85.800000          High income
# 40    Costa Rica         CRI     15.022      45.960000  Upper middle income
# 50       Ecuador         ECU     21.070      40.353684  Upper middle income
# 60         Gabon         GAB     30.555       9.200000  Upper middle income
# 70     Greenland         GRL     14.500      65.800000          High income
# 80         India         IND     20.291      15.100000  Lower middle income
# 90    Kazakhstan         KAZ     22.730      54.000000  Upper middle income
# 100        Libya         LBY     21.425      16.500000  Upper middle income
# ...

# %%
sub10.iat[10,0]
#so it count as matrix mathod
# Out:
# 'Libya'

# %%
sub10.at[10,'CountryName']
#so it pick label 10 in the column
# Out:
# 'Azerbaijan'

# %% [markdown]
# ---

# %%
#Introduction to Seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
#Distribution:
vis1=sns.distplot(stats['InternetUsers'])
plt.rcParams['figure.figsize']=8,4
#by writing sns.+tab we can see all features.

# %%
vis1=sns.distplot(stats['InternetUsers'],bins=40)

# %%
#Boxplots
vis2=sns.boxplot(data=stats,x='IncomeGroup',y='BirthRate')
#compare vis1 and vis2 charts
#this black dots are outliars.
#observation- High income grp having low birth rate and low income having high birthrate.

# %%
#GO AND VISIT SEABORN GALLARY ON GOOGLE

# %% [markdown]
# ---

# %%
#Visualing with seaborn part 1

# %%
vis3=sns.lmplot(data=stats,x='InternetUsers',y='BirthRate')
#lm is tends for linear plot
#We can observe that size of this chart doesnt chanded  although we have written that line (8,4),
#Its because we can read line by clicking tab of function that 'Plot data and regression model fits across a FacetGrid.'
#that means chart will take size automatically.
#we can change it by size and to change length:width we use aspect.

# %%
vis3=sns.lmplot(data=stats,x='InternetUsers',y='BirthRate',fit_reg=False,size=10,aspect=2)
#so now the line is not there.Also conclusion is similar as of vis2.

# %%
vis3=sns.lmplot(data=stats,x='InternetUsers',y='BirthRate',hue='IncomeGroup')
#hue is for colo addition.

# %%
vis3=sns.lmplot(data=stats,x='InternetUsers',y='BirthRate',hue='IncomeGroup',fit_reg=False)

# %% [markdown]
# ---

# %%
#ADVANCED TUTORIAL

# %%
#Marker Size
vis3=sns.lmplot(data=stats,x='InternetUsers',y='BirthRate',hue='IncomeGroup',fit_reg=False,scatter_kws={'s':100})
#scatter_kws={'s':100}
#in code of scatter_kws which is code to change size of dots ,which written in turm of 's',so to assing size of dots,
#we have createdd dictonary so now 's' will print that value and we get output.
