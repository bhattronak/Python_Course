# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Ronak.Bhatt\\Desktop\\Python programming course'

# %%
movies=pd.read_csv('MovieRatings.csv')

# %%
len(movies)
# Out:
# 559

# %%
movies
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# 2                    52                  20             2009
# 3                    84                  18             2010
# 4                    70                  20             2009
# ..                  ...                 ...              ...
# 554                  36                  50             2011
# 555                  52                  18             2009
# 556                  73                  65             2007
# 557                  87                  24             2009
# 558                  42                  80             2011
#
# [559 rows x 6 columns]

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns=(['Film', 'Genre','CriticRatings', 'AudienceRatings',
       'BudgetMillions', 'Year'])

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRatings  AudienceRatings  \
# 0  (500) Days of Summer      Comedy             87               81
# 1            10,000 B.C.  Adventure              9               44
# 2             12 Rounds      Action             30               52
# 3              127 Hours  Adventure             93               84
# 4              17 Again      Comedy             55               70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    object
#  1   Genre            559 non-null    object
#  2   CriticRatings    559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   BudgetMillions   559 non-null    int64
#  5   Year             559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.describe()
# Out:
#        CriticRatings  AudienceRatings  BudgetMillions         Year
# count     559.000000       559.000000      559.000000   559.000000
# mean       47.309481        58.744186       50.236136  2009.152057
# std        26.413091        16.826887       48.731817     1.362632
# min         0.000000         0.000000        0.000000  2007.000000
# 25%        25.000000        47.000000       20.000000  2008.000000
# 50%        46.000000        58.000000       35.000000  2009.000000
# 75%        70.000000        72.000000       65.000000  2010.000000
# max        97.000000        96.000000      300.000000  2011.000000

# %%
movies.Film.astype('category')
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: category
# Categories (559, object): [(500) Days of Summer, 10,000 B.C., 12 Rounds, 127 Hours, ..., Youth in Revolt, Zodiac, Zombieland, Zookeeper]

# %%
movies.Film=movies.Film.astype('category')
#its done so that datatype of Film is change from object to category.we can do it with other variables too.

# %%
movies.info()
#so now datatype has changes to category
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    category
#  1   Genre            559 non-null    object
#  2   CriticRatings    559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   BudgetMillions   559 non-null    int64
#  5   Year             559 non-null    int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 47.4+ KB

# %%
movies.Genre=movies.Genre.astype('category')
movies.Year=movies.Year.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    category
#  1   Genre            559 non-null    category
#  2   CriticRatings    559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   BudgetMillions   559 non-null    int64
#  5   Year             559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 40.3 KB

# %%
movies.Genre.cat.categories
#to get unique name of same column
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
movies.describe()
#so now year is not including because its category now not int.
# Out:
#        CriticRatings  AudienceRatings  BudgetMillions
# count     559.000000       559.000000      559.000000
# mean       47.309481        58.744186       50.236136
# std        26.413091        16.826887       48.731817
# min         0.000000         0.000000        0.000000
# 25%        25.000000        47.000000       20.000000
# 50%        46.000000        58.000000       35.000000
# 75%        70.000000        72.000000       65.000000
# max        97.000000        96.000000      300.000000

# %% [markdown]
# ---

# %%
#Working with JointPlots

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
#Jointplots

# %%
j=sns.jointplot(data=movies,x='CriticRatings',y='AudienceRatings')

# %%
j=sns.jointplot(data=movies,x='CriticRatings',y='AudienceRatings',kind='hex')
#hex is usefull while creating clusters very easily
#we can also change kind and look effects.

# %%
j=sns.jointplot(data=movies,x='CriticRatings',y='AudienceRatings',kind='kde')
#which we will see by kdeplot in upcoming lecture

# %%
#<<<< CHART 1

# %% [markdown]
#  ---

# %%
#HISTOGRAM

# %%
#Method 1
#Already know this method
m1=sns.distplot(movies.AudienceRatings,bins=30)

# %%
m1=sns.distplot(movies.CriticRatings,bins=15)

# %%
#Method 2
#without seaborn
sns.set_style('whitegrid') #this line is to add grid on background
n1=plt.hist(movies.AudienceRatings,bins=30)
#so slightly diffrent than seaborn

# %%
#<<<<---CHART 2

# %%
sns.set_style('darkgrid') #this line is to add grid on background
n1=plt.hist(movies.CriticRatings,bins=30)

# %%
#<<<<---CHART 3

# %% [markdown]
# ---

# %%
#Stacked Histogram in PYTHON
plt.hist(movies.BudgetMillions)
#which showa budget of every film,but what if i want to see perticualr for comedy movies or action movies?Lets look at next step
plt.show()

# %%
#step 1
movies.Genre=='Drama'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 554    False
# 555    False
# 556    False
# 557    False
# 558    False
# Name: Genre, Length: 559, dtype: bool

# %%
#step 2
movies[movies.Genre=='Drama']
# Out:
#                     Film  Genre  CriticRatings  AudienceRatings  \
# 10            88 Minutes  Drama              5               51
# 11    A Dangerous Method  Drama             79               89
# 13        A Serious Man   Drama             89               64
# 18          Albert Nobbs  Drama             53               43
# 23       All Good Things  Drama             33               64
# ..                   ...    ...            ...              ...
# 529            War Horse  Drama             77               73
# 532  Water For Elephants  Drama             60               72
# 534     We Own the Night  Drama             55               63
# 541             Whip It   Drama             84               73
# 545        Winter's Bone  Drama             94               73
#
#      BudgetMillions  Year
# 10               30  2007
# 11               20  2011
# 13                7  2009
# 18                8  2011
# 23               20  2010
# ..              ...   ...
# 529              66  2011
# 532              38  2011
# 534              21  2007
# 541              15  2009
# 545               2  2010
#
# [101 rows x 6 columns]

# %%
#step 3
movies[movies.Genre=='Drama'].BudgetMillions
# Out:
# 10     30
# 11     20
# 13      7
# 18      8
# 23     20
#        ..
# 529    66
# 532    38
# 534    21
# 541    15
# 545     2
# Name: BudgetMillions, Length: 101, dtype: int64

# %%
plt.hist(movies[movies.Genre=='Drama'].BudgetMillions)
#same we can do for Action ,comedy etc..
plt.show()

# %%
plt.hist(movies[movies.Genre=='Drama'].BudgetMillions,bins=15)
plt.hist(movies[movies.Genre=='Action'].BudgetMillions,bins=15)
plt.hist(movies[movies.Genre=='Thriller'].BudgetMillions,bins=15)
#so here they are hiding each others,what if we want transferancy,look at next step
plt.show()

# %%
#step 1
#movies[movies.Genre=='Drama'].BudgetMillions
#movies[movies.Genre=='Action'].BudgetMillions

# %%
#step 2
#put this 2 in 1 list
#so we have final list as following
#[movies[movies.Genre=='Drama'].BudgetMillions,movies[movies.Genre=='Action'].BudgetMillions]

# %%
#step 3
#put this list in plt.hist(list,bin=15)

# %%
plt.hist([movies[movies.Genre=='Drama'].BudgetMillions,movies[movies.Genre=='Action'].BudgetMillions],bins=15)
plt.show()
#so we have this final chart

# %%
plt.hist([movies[movies.Genre=='Drama'].BudgetMillions,movies[movies.Genre=='Action'].BudgetMillions,movies[movies.Genre=='Thriller'].BudgetMillions],bins=5)
plt.show()
#so now we have 3 parameters

# %%
plt.hist([movies[movies.Genre=='Drama'].BudgetMillions,\
          movies[movies.Genre=='Action'].BudgetMillions,\
          movies[movies.Genre=='Thriller'].BudgetMillions],\
         stacked=True,bins=10)
plt.show()
#so here we have written stacked=True which takes all the bars in one line as shown

# %%
#so this code is getting longer and longer to avoid it look at next steps.

# %%
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
for gen in movies.Genre.cat.categories:
    print(gen)
#gen is for Genre for convinient
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
a=list()

# %%
a.append(1)

# %%
a
#so we add member like wise by creating empty list
#remember append will take one element at a time
# Out:
# [1]

# %%
list1=list()
labl=list()
for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre==gen].BudgetMillions)
    labl.append(gen)
print(list1)
print(labl)
# Out:
# [2       20
# 5      200
# 15      35
# 29      20
# 30      20
#       ...
# 531    130
# 542     35
# 546    150
# 547    160
# 557     24
# Name: BudgetMillions, Length: 154, dtype: int64, 1      105
# 3       18
# 19     200
# 21      45
# 24      40
# 32      78
# 46      20
# 65      38
# 68     140
# 130     73
# 165     12
# 166    125
# 167    250
# 168    150
# 176     36
# 178    150
# 192     70
# 193     60
# 241     60
# 272     37
# 341     19
# 363     70
# 386    130
# 401    155
# 459     59
# 463     25
# 506     38
# 540    100
# 548     60
# Name: BudgetMillions, dtype: int64, 0       8
# 4      20
# 6      30
# 8      28
# 9       8
#        ..
# 552    80
# 553    22
# 554    50
# 555    18
# 558    80
# Name: BudgetMillions, Length: 172, dtype: int64, 10     30
# 11     20
# 13      7
# 18      8
# 23     20
#        ..
# 529    66
# 532    38
# 534    21
# 541    15
# 545     2
# Name: BudgetMillions, Length: 101, dtype: int64, 7      32
# 12     35
# 20     40
# 28      5
# 59     26
# 88     10
# 97     25
# 100    30
# 103    50
# 109    20
# 126    40
# 135    19
# 137    30
# 160    20
# 161    15
# 175    10
# 194     2
# 246    35
# 259    25
# 285    20
# 286    30
# 292     1
# 293     3
# 294     5
# 311    18
# 315    12
# 321    42
# 322     4
# 332    10
# 333    11
# 335    40
# 343    25
# 349     8
# 355    13
# 373    50
# 404    20
# 414    12
# 416    40
# 426     5
# 429    15
# 453    18
# 461    40
# 462    37
# 464    16
# 465    25
# 475     9
# 478    38
# 486    16
# 521    10
# Name: BudgetMillions, dtype: int64, 16      45
# 42      17
# 78      50
# 108     60
# 136     35
# 201      0
# 208     80
# 244     17
# 250     20
# 255     40
# 266     56
# 284     15
# 290     30
# 354     35
# 507    110
# 510     15
# 524      5
# 525      2
# Name: BudgetMillions, dtype: int64, 25     100
# 72      60
# 95      20
# 105     15
# 179    150
# 180     60
# 189     40
# 225     27
# 237      4
# 243     25
# 253     20
# 261     20
# 263    130
# 267     70
# 282     85
# 358     32
# 385     51
# 389     20
# 394    110
# 406    185
# 407    100
# 408     20
# 419     90
# 424     48
# 432     13
# 471     15
# 481    100
# 491     35
# 494     21
# 498     22
# 503     35
# 513     30
# 515     35
# 519     75
# 522     40
# 556     65
# Name: BudgetMillions, dtype: int64]
# ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
plt.hist(list1,bins=5)
plt.show()

# %%
plt.hist(list1,bins=30,label=labl,stacked=True)
plt.legend()#to show labels
plt.show()

# %%
#<<<--- CHART 4

# %% [markdown]
# ---

# %%
#Creating a KDE PLOT

# %%
vis1=sns.lmplot(data=movies,x='CriticRatings',y='AudienceRatings',hue='Genre',fit_reg=False,size=5,aspect=1.5)

# %%
j=sns.jointplot(data=movies,x='CriticRatings',y='AudienceRatings',kind='kde')
#which we have seen earlier.

# %%
k1=sns.kdeplot(movies.CriticRatings,movies.AudienceRatings)
#so it says maximum density point.And how density is distributed

# %%
k1=sns.kdeplot(movies.CriticRatings,movies.AudienceRatings,shade=True,shade_lowest=False)
#shade_lowest=False is used to on the background grids if shade is True.

# %%
k1=sns.kdeplot(movies.CriticRatings,movies.AudienceRatings,shade=True,shade_lowest=False,cmap='Greens')
#so cmap is to color the graph.But make sure we write Reds not red for every color.R should be capital.
#but we dont have outer line clear visible,so do it without shading and overlap both.

# %%
kb1=sns.kdeplot(movies.CriticRatings,movies.AudienceRatings,cmap='Reds')
#so without shading color change

# %%
k1=sns.kdeplot(movies.CriticRatings,movies.AudienceRatings,shade=True,shade_lowest=False,cmap='Greens')
kb1=sns.kdeplot(movies.CriticRatings,movies.AudienceRatings,cmap='Reds')
#so now we have overlaped both so have nice look.

# %%
k1=sns.kdeplot(movies.CriticRatings,movies.AudienceRatings,shade=True,shade_lowest=False,cmap='Reds')
kb1=sns.kdeplot(movies.CriticRatings,movies.AudienceRatings,cmap='Reds')

# %%
k1=sns.kdeplot(movies.CriticRatings,movies.AudienceRatings,shade=True,shade_lowest=False,cmap='Reds')
#So compare this and aboves chart,we can see that above one is much batter.

# %% [markdown]
# ---

# %%
#WORKING WITH SUBPLOTS()

# %%
sns.set_style('dark')
#to turn off grids
k1=sns.kdeplot(movies.BudgetMillions,movies.AudienceRatings)
#so its closer to normal distribution

# %%
k1=sns.kdeplot(movies.BudgetMillions,movies.CriticRatings)
#its closer to uniform distribution

# %%
f,ax=plt.subplots(2,1)

# %%
f,ax=plt.subplots(2,2)

# %%
f,axes=plt.subplots(1,2,figsize=(12,6))
k1=sns.kdeplot(movies.BudgetMillions,movies.AudienceRatings,ax=axes[0])
k2=sns.kdeplot(movies.BudgetMillions,movies.CriticRatings,ax=axes[1])
#initial f is for figure.its array.
#axes(we can give any name to this array) is parameter which locate where to put perticular chart in subplot
#figsize=(12,6)is used to control size of plot
#if its multiple row and multiple column,than we have to write ax=axes[2,2],otherwise axes[1] gives array.

# %%
axes
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000226F2D3FC08>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000226F2F934C8>],
#       dtype=object)

# %%
f,axes=plt.subplots(2,2,figsize=(12,6))
k1=sns.kdeplot(movies.BudgetMillions,movies.AudienceRatings,ax=axes[0,0])
k2=sns.kdeplot(movies.BudgetMillions,movies.CriticRatings,ax=axes[1,1])

# %%
f,axes=plt.subplots(1,2,figsize=(12,6),sharex=True,sharey=True)
k1=sns.kdeplot(movies.BudgetMillions,movies.AudienceRatings,ax=axes[0])
k2=sns.kdeplot(movies.BudgetMillions,movies.CriticRatings,ax=axes[1])
k1.set(xlim=(-20,160))
#sharex=True will take the same limit of x axis in each subplot
#same for sharey is true.
#(xlim=(-20,160)) will set limit of x axis
# Out:
# [(-20, 160)]
